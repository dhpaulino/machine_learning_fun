# %%
import pandas as pd
import seaborn as sns
sns.set(style="ticks")

# %%
df = pd.read_csv("data/iris.data", names=["sepal_length", "sepal_width","petal_length", "petal_width", "class"])

# %% [markdown]
# ## Correlation
# * sepal_length has strong correlation with petal_length and petal_width
# * petal_length ahas strong correlation with petal_width
# * We can use 2 of the 4 feature (or components of it)

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.pairplot(data=df, hue="class")
